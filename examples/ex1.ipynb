# %%
import toolbox

# %%
toolbox.get_local_ip()
# Out:
# '192.168.10.60'

# %%
import subprocess
subprocess.run(["pwd"])
# Out:
# /synology/data3/proj_asa/ashot/codebase/toolbox/examples
# CompletedProcess(args=['pwd'], returncode=0)

# %%
toolbox.git_info()
# Out:
# ('master', '8a6b59abadfc74c4188223de5cd423151f4d4e0d')

# %%
toolbox.get_launch_info(string=False)
# Out:
# fatal: ambiguous argument 'HEAD': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# {'interpreter': '/home/amatevosyan/venvs/base/bin/python',
#  'datetime': datetime.datetime(2026, 3, 27, 0, 56, 3, 479690),
#  'args': ['/home/amatevosyan/venvs/base/lib/python3.10/site-packages/ipykernel_launcher.py',
#   '--f=/run/user/5328/jupyter/runtime/kernel-v3af842492bf5b550f2df164b6295c8be4a49fccf3.json'],
#  'hostname': 'AMatevosyanP2L',
#  'local_ip': '192.168.10.60',
#  'git_branch': None,
#  'git_commit': None}
